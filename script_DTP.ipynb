# %%
# CALLS scripts.py to
# (1) generate data
# (2) train models
# (3) plot results

import gen_data

# FOR LOOP over parameters
# update parameters in YAML
import train_models
# Out:
# generating training trials ...
# generating validation trials ...
# generating testing trials ...
# data generation complete
# ResNet Architecture: 3-in | 3x256 | 3-out
# n_train = 2000
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /scratch/3513948.sched-torque.pace.gatech.edu/ipykernel_203566/2999128984.py in <module>
#       8 # FOR LOOP over parameters
#       9 # update parameters in YAML
# ---> 10 import train_models
#
# /storage/coda1/p-sbryngelson3/0/ssims36/multiscale_rp/train_models.py in <module>
#      89
#      90     # create dataset object
# ---> 91     dataset = net.DataSet(train_data, val_data, test_data, dt, step_size, model_steps)
#      92     model_name = 'model_D{}.pt'.format(step_size)
#      93
#
# /storage/coda1/p-sbryngelson3/0/ssims36/multiscale_rp/src/utils.py in __init__(self, train_data, val_data, test_data, dt, step_size, n_forward)
# ...
